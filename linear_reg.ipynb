# %%
import numpy as np

# %%
x = np.random.uniform(0,10,10,)
y = 7*x + 5

# %%
x,y
# Out:
# (array([0.24211391, 7.51635165, 0.44481267, 4.85664413, 6.31979368,
#         3.17443263, 6.62617255, 4.97252412, 3.90384355, 0.45104024]),
#  array([ 6.69479734, 57.61446153,  8.11368872, 38.99650889, 49.23855573,
#         27.2210284 , 51.38320782, 39.80766885, 32.32690487,  8.15728167]))

# %%
n = len(x)

Sxy = sum(x*y)- (1.0/n)*sum(x)*sum(y)

Sxx = sum(x**2) - (1.0/n)*sum(x)**2

beta1 = Sxy/Sxy

alpha1 = sum(y)/n - beta1*(sum(x)/n)

print(alpha1,beta1)
# Out:
# 28.10463747082155 1.0

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x.reshape(n, 1),y.reshape(n, 1))

alpha2 = lr.intercept_
beta2 = lr.coef_

print(alpha2, beta2)
# Out:
# [5.] [[7.]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.scatter(x,y,c ='g')

x_ = np.linspace(min(x),max(x),100)
y_ = alpha1+ beta1*x_
plt.plot(x_,y_,'m--')

plt.legend(['Datas', 'LR line'])
plt.title("Linear Regression 1")
# Out:
# Text(0.5, 1.0, 'Linear Regression 1')

# %%
plt.figure(figsize=(15,10))
plt.scatter(x,y,c ='g')

x_ = np.linspace(min(x),max(x),100)
y_ = alpha2+ beta2*x_
plt.plot(x_,y_,'r--')

plt.legend(['Datas', 'LR line'])
plt.title("Linear Regression 1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-cce49328709a> in <module>
#       4 x_ = np.linspace(min(x),max(x),100)
#       5 y_ = alpha2+ beta2*x_
# ----> 6 plt.plot(x_,y_,'r--')
#       7
#       8 plt.legend(['Datas', 'LR line'])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...
